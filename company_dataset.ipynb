# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_excel("Data_Analyst_Screening_Reference.xlsx")

# %%
df
# Out:
#    Order_ID Order_Date Region Salesperson   Product     Category  Quantity  \
# 0   ORD1001 2026-01-05   West       Rahul  Keyboard  Accessories         8
# 1   ORD1002 2026-01-08   West       Rahul     Mouse  Accessories         4
# 2   ORD1003 2026-01-11   East        Amit    Laptop     Hardware         2
# 3   ORD1004 2026-01-14  North        Amit  Keyboard  Accessories        14
# 4   ORD1005 2026-01-17  North       Rahul  Keyboard  Accessories         6
# 5   ORD1006 2026-01-20   West        Neha     Mouse  Accessories         6
# 6   ORD1007 2026-01-23   East       Priya    Laptop     Hardware        10
# 7   ORD1008 2026-01-26   West        Amit    Laptop     Hardware         4
# 8   ORD1009 2026-01-29   West       Priya  Keyboard  Accessories         6
# 9   ORD1010 2026-02-01  South        Neha   Monitor     Hardware        13
# 10  ORD1011 2026-02-04  South        Neha  Keyboard  Accessories         2
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Order_ID         30 non-null     object
#  1   Order_Date       30 non-null     datetime64[ns]
#  2   Region           30 non-null     object
#  3   Salesperson      30 non-null     object
#  4   Product          30 non-null     object
#  5   Category         30 non-null     object
#  6   Quantity         30 non-null     int64
#  7   Unit_Price       30 non-null     int64
#  8   Discount         30 non-null     float64
#  9   Gross_Sales      30 non-null     int64
#  10  Net_Revenue      30 non-null     int64
#  11  Cost             30 non-null     int64
#  12  Profit           30 non-null     int64
#  13  Customer_Rating  30 non-null     int64
# dtypes: datetime64[ns](1), float64(1), int64(7), object(5)
# memory usage: 3.4+ KB

# %%
df.columns
# Out:
# Index(['Order_ID', 'Order_Date', 'Region', 'Salesperson', 'Product',
#        'Category', 'Quantity', 'Unit_Price', 'Discount', 'Gross_Sales',
#        'Net_Revenue', 'Cost', 'Profit', 'Customer_Rating'],
#       dtype='object')

# %%
df.groupby(by='Region') ['Profit'].sum()
# Out:
# Region
# East     444418
# North    191228
# South    101452
# West      87375
# Name: Profit, dtype: int64

# %%
# Which region generated the highest Net Revenue?
df.groupby(by='Region') ['Net_Revenue'].sum().idxmax()                      # .idxmax()   give us index value
# Out:
# 'East'

# %%
# Which product has the highest total Quantity Sold?
df.groupby(by='Product') ['Quantity'].sum().idxmax()
# Out:
# 'Mouse'

# %%
df.groupby('Product')['Quantity'].sum().sort_values(ascending=False)
# Out:
# Product
# Mouse       81
# Keyboard    74
# Monitor     49
# Laptop      42
# Name: Quantity, dtype: int64

# %%
# . Which salesperson generated the highest Profit?

df.groupby(by='Salesperson') ['Profit'].sum().idxmax()
# Out:
# 'Priya'

# %%
df['Category'].value_counts()
# Out:
# Category
# Accessories    19
# Hardware       11
# Name: count, dtype: int64

# %%
#  What percentage of total orders belongs to the Hardware category?
(df['Category'] == 'Hardware' ).mean()*100
# Out:
# np.float64(36.666666666666664)

# %%
# Which product has the highest average selling price after discount?

df.groupby('Product')['Unit_Price'].mean() * (1 - df['Discount'].mean())
# Out:
# Product
# Keyboard     1674.0
# Laptop      60450.0
# Monitor     11160.0
# Mouse         837.0
# Name: Unit_Price, dtype: float64

# %%
# Identify the order with the highest Profit and mention its Order ID.
df.loc[df['Profit'].idxmax(), ['Order_ID', 'Profit']]
# Out:
# Order_ID    ORD1016
# Profit       216348
# Name: 15, dtype: object

# %%
# What is the difference between Gross Sales and Net Revenue for the entire dataset?
df['Gross_Sales'].sum() - df['Net_Revenue'].sum()
# Out:
# np.int64(134010)

# %%
# Q11. Which product generated the highest total Net Revenue?
f
df.groupby(by='Product')['Net_Revenue'].sum().idxmax()
# Out:
# 'Laptop'

# %%
# 12 Which region had the lowest total Profit?

df.groupby(by='Region')['Profit'].sum().idxmin()
# Out:
# 'West'

# %%
# Which salesperson handled the highest total Quantity Sold?


df.groupby(by='Salesperson')['Quantity'].sum().idxmax()
# Out:
# 'Priya'

# %%
# Which product received the highest average discount?


df.groupby(by='Product')['Discount'].mean().idxmax()
# Out:
# 'Mouse'

# %%
# Which product generated the highest total Profit?

df.groupby(by='Product')['Profit'].sum().idxmax()
# Out:
# 'Laptop'

# %%
# How many orders had a discount greater than 10%?
df[df['Discount']>0.10] ['Order_ID'].nunique()
# Out:
# 8

# %%
(df['Discount'] > 0.10).sum()
# Out:
# np.int64(8)

# %%
# What is the average Net Revenue per order? 
df['Net_Revenue'].mean()
                   # If each row represents one order,
# Out:
# np.float64(113003.0)

# %%
df.groupby(by='Order_ID')['Net_Revenue'].sum().mean()                          ## same order id repeat
# Out:
# np.float64(113003.0)

# %%
# Which region has the highest average Profit per order?

df.groupby(by='Region')['Profit'].mean().idxmax()
# Out:
# 'East'

# %%
# Which product has the highest average profit after applying the average discount?


s = df.groupby(by='Product') ['Profit'].mean() * (1-df['Discount'].mean()/100)
s.idxmax()
# Out:
# 'Laptop'

# %%
# Which region has the highest average Net Revenue after considering the average discount?

s= df.groupby('Region')['Net_Revenue'].mean()  *  (1 - df['Discount'].mean()/100)
s.idxmax()
# Out:
# 'East'

# %%
# Which salesperson has the highest average Quantity Sold per order?
df.groupby('Salesperson')['Quantity'].mean().idxmax()
# Out:
# 'Priya'

# %%
df.groupby('Product')['Net_Revenue'].sum().idxmax()
# Out:
# 'Laptop'

# %% [markdown]
# # Business based Q

# %% [markdown]
# # 1  Increase profit
#
# Question:
#
# ### If the company wants to increase profit, which would you recommend focusing on: increasing quantity, reducing discount, or reducing cost? Give one reason based on the data.
#
#
# # How you should say it in an interview:
#
# I would recommend reducing the discount. Based on the data, reducing the discount would increase the Net Revenue while keeping the quantity and cost unchanged, which can help improve profit.

# %% [markdown]
# # Q 2  "The region with the highest sales must also have the highest profit." Is this necessarily true?
#
# Correct answer: False
#
# Interview answer:
#
# No, this statement is not necessarily true. Sales and profit are different metrics. A region can have high sales but lower profit because of higher discounts, costs, or other expenses.

# %% [markdown]
# # Q3 . Discount reduced by 5 percentage points
#
# Question:
#
# ## Suppose the company reduces the discount on all products by 5 percentage points while keeping quantity and cost the same. What would you expect to happen to Net Revenue and Profit?
#
# Interview answer:
#
# I would expect Net Revenue to increase because customers would receive a lower discount. Since the cost remains unchanged, profit should also increase

# %% [markdown]
# # Q4. Highest quantity = highest profit?
#
# Question:
#
# "The product with the highest quantity sold must also generate the highest profit."
#
# Correct answer: False ❌
#
# Interview answer:
#
# I disagree. The statement is not necessarily true. In this dataset, Mouse has the highest total quantity sold, but Laptop generates the highest total profit. This shows that profit also depends on selling price, discount, and cost, not only quantity sold.

# %% [markdown]
# # Q 5. Q21 — Profit vs Quantity
#
# "If we double the quantity sold for every product, profit will also exactly double."
#
# ANS :
#  I Disagree.this statement is not necessarily true. based on the data profit is not only depends upon the Quantity sold but also depends upon factors such as discount,seeling price and the cost..
#
#
#  # Q 6. — Discount Scenario
#
# The manager says:
#
# "Giving a higher discount will always increase total profit because it will attract more customers."
#
# ANS :
# I disagree. This statement is not necessarily true. A higher discount reduces the revenue earned per sale and can reduce profit
#
# #  Q 7. — Product Strategy
#
# The company wants to focus on the product that contributes the most profit.
#
# Would you recommend focusing on the product with the highest quantity sold or the product with the highest total profit
#
# ANS :  i would recommend to focus on the product with highest total profit bcz it contributes the most profit to the company.
#
# # Q 8 . Regional Performance
#
# East has the highest Net Revenue in the dataset.
#
# A manager says:
#
# ### "Therefore, East is automatically the most efficient region."
#
# Do you agree? What additional metric would you check?
#
# I disagree. We should not determine the most efficient region based only on Net Revenue. I would also check total profit, profit margin, average order value, and the number of orders to evaluate the region's overall performance.
#
# # Q 9 — Cost Reduction
#
# ### Suppose the company reduces the cost of every product by 10%, while quantity, selling price, and discount remain unchanged.
#
# What would you expect to happen to profit?
#
# Explain your reasoning:
# I would expect profit to increase because the product cost is reduced by 10%, while the selling price, quantity, and discount remain unchanged. This means the company keeps more profit from each sale.

# %% [markdown]
# # 10 "Our revenue increased, so our business performance definitely improved."
#  I disagree with above statement . we should not determine the business performance based on only revenue .i would also check the total profit,total margine and the overall performanace.
#
#  # Q 11 .Two products have the same quantity sold, but Product A generates much higher profit than Product B.
#
# What factors could explain this difference?
#
# The difference could be explained by factors such as selling price, product cost, discount, and product quality. For example, if Product A has a higher selling price or lower cost than Product B, it can generate higher profit even when both products have the same quantity sold.
#
# # Q 12 Sales Increase
#
# Suppose sales increase by 30%, but profit increases by only 5%.
#
# What three factors would you investigate?
#
#
# The difference could be explained by factors such as selling price, product cost, discount, and product quality. For example, if Product A has a higher selling price or lower cost than Product B, it can generate higher profit even when both products have the same quantity sold.

# %% [markdown]
#  # Scenario-Based

# %% [markdown]
# # 1. Data Quality: You receive a sales file where 5% of the rows have missing Region values. What steps would you take before using the data for a management report?
#
# First, I would check how many Region values are missing and why they are missing. I would check if I can get the correct Region from other data. If not, I would use a suitable method like mode or mark it as Unknown. Finally, I would check the data again before using it in the report.
#
# # 2.Duplicate Data:
# You discover that the same Order ID appears twice. How would you determine whether it is a genuine duplicate or two legitimate transactions?
#
# Ans :
#   First, I would check how many Order IDs are repeated in the dataset. Then, I would compare the complete rows for those Order IDs. If all the details are the same, I would consider it a duplicate. If the other details are different, I would check whether they are legitimate transactions
#
#
# # 3 Management notices that sales increased by 20%, but profit increased by only 5%. What factors would you investigate?
#
#   ans :
# The difference could be explained by factors such as selling price, product cost, discount, and product quality. For example, if Product A has a higher selling price or lower cost than Product B, it can generate higher profit even when both products have the same quantity sold.
#
# # 4 Your manager asks for a sales report within 30 minutes, but you notice some data is missing. What would you do?
#
# First, I would check what type of data is missing and why it is missing. For example, if Region values are missing, I would check whether I can match or recover the Region from other data. If I cannot recover it, I would use a suitable method such as mode or mark it as Unknown. Finally, I would validate the data again before using it in the report.

# %% [markdown]
# #  Business Problem

# %% [markdown]
# # A company sells laptops, monitors, keyboards, and mice across different regions. Management has noticed that revenue is increasing, but profit margins are not improving at the same rate.
#
# You are given the attached sales dataset. As a Data Analyst, answer the following:
#
# a) What are the first 3 things you would analyze?
#
# b) Which columns from the dataset would you use for the analysis?
#
# c) What type of Excel/SQL analysis would you perform?
#
# d) What 3 KPIs would you show management?
#
# e) Based on your analysis approach, suggest one possible business action that could improve profitability.
#
#
#
#
# a : ans :  First, I would analyze the discount given on each product. Second, I would compare the selling price of each product. Third, I would compare the cost of each product to understand which factors are affecting the profit margin.
#
#
# b :  I would use columns such as Product, Region, Quantity, Unit Price, Discount, Cost, Gross Sales, Net Revenue, and Profit.
#
#
# d) KPIs → Net Revenue, Total Profit, Profit Margin
#
# e) Possible action → reduce unnecessary discounts and focus on products/regions with stronger profit margins.

# %% [markdown]
# # Business Problem 2 — Sales & Profitability
# Scenario
#
# A company sells Laptops, Monitors, Keyboards, and Mice across different regions. Management wants to understand which products and regions are contributing most to revenue and profit.
#
# # 1 What are the first 3 things you would check when you receive this sales dataset?
#
# first i would analyse discount given by each product .because a higher discount can reduce profit margin second i would camare the seeling price of each product third i would check the cost price of product which can helps to  understand how it affects the overall profit.
#
#
# # 2.You find some missing values in the Region and Discount columns. What would you do before analyzing the data?
#
# i would check in region and discount columns how many missing values are there and why it is missing . i would check if i can get correct region and discount from othere data if not i would use sutaiable method  based on the data like mode and mark as unknown for region and anothere value for the discound like mean.. finally i would check again before get it in to the report.
